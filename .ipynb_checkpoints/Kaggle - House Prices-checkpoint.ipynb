# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LassoCV
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import KFold, learning_curve, cross_val_score, ShuffleSplit, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from scipy.stats import skew
from statsmodels.stats.outliers_influence import variance_inflation_factor
import kaggle
# %matplotlib inline
sns.set_style('darkgrid')
pd.set_option('display.max_columns', 100)

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

all_data = pd.concat([df_train, df_test], ignore_index=True)
all_data['SalePrice'].fillna(0, inplace=True)
original_data = all_data.copy()
all_data.drop(['Id'], axis=1, inplace=True)

print('Train Set: {}, {}'.format(df_train.shape[0], df_train.shape[1]))
print('Test Set: {}, {}'.format(df_test.shape[0], df_test.shape[1]))
print('All Data: {}, {}'.format(all_data.shape[0], all_data.shape[1]))

submission = pd.DataFrame(columns=['Id', 'SalePrice'])
submission['Id'] = df_test['Id']
submission['SalePrice'] = 0
# Out:
# Train Set: 1460, 81
# Test Set: 1459, 80
# All Data: 2919, 80

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 80 columns):
# 1stFlrSF         2919 non-null int64
# 2ndFlrSF         2919 non-null int64
# 3SsnPorch        2919 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2919 non-null int64
# BldgType         2919 non-null object
# BsmtCond         2837 non-null object
# BsmtExposure     2837 non-null object
# BsmtFinSF1       2918 non-null float64
# BsmtFinSF2       2918 non-null float64
# BsmtFinType1     2840 non-null object
# BsmtFinType2     2839 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2838 non-null object
# BsmtUnfSF        2918 non-null float64
# CentralAir       2919 non-null object
# Condition1       2919 non-null object
# Condition2       2919 non-null object
# Electrical       2918 non-null object
# EnclosedPorch    2919 non-null int64
# ExterCond        2919 non-null object
# ExterQual        2919 non-null object
# Exterior1st      2918 non-null object
# Exterior2nd      2918 non-null object
# Fence            571 non-null object
# FireplaceQu      1499 non-null object
# Fireplaces       2919 non-null int64
# Foundation       2919 non-null object
# FullBath         2919 non-null int64
# Functional       2917 non-null object
# GarageArea       2918 non-null float64
# GarageCars       2918 non-null float64
# GarageCond       2760 non-null object
# GarageFinish     2760 non-null object
# GarageQual       2760 non-null object
# GarageType       2762 non-null object
# GarageYrBlt      2760 non-null float64
# GrLivArea        2919 non-null int64
# HalfBath         2919 non-null int64
# Heating          2919 non-null object
# HeatingQC        2919 non-null object
# HouseStyle       2919 non-null object
# KitchenAbvGr     2919 non-null int64
# KitchenQual      2918 non-null object
# LandContour      2919 non-null object
# LandSlope        2919 non-null object
# LotArea          2919 non-null int64
# LotConfig        2919 non-null object
# LotFrontage      2433 non-null float64
# LotShape         2919 non-null object
# LowQualFinSF     2919 non-null int64
# MSSubClass       2919 non-null int64
# MSZoning         2915 non-null object
# MasVnrArea       2896 non-null float64
# MasVnrType       2895 non-null object
# MiscFeature      105 non-null object
# MiscVal          2919 non-null int64
# MoSold           2919 non-null int64
# Neighborhood     2919 non-null object
# OpenPorchSF      2919 non-null int64
# OverallCond      2919 non-null int64
# OverallQual      2919 non-null int64
# PavedDrive       2919 non-null object
# PoolArea         2919 non-null int64
# PoolQC           10 non-null object
# RoofMatl         2919 non-null object
# RoofStyle        2919 non-null object
# SaleCondition    2919 non-null object
# SalePrice        2919 non-null float64
# SaleType         2918 non-null object
# ScreenPorch      2919 non-null int64
# Street           2919 non-null object
# TotRmsAbvGrd     2919 non-null int64
# TotalBsmtSF      2918 non-null float64
# Utilities        2917 non-null object
# WoodDeckSF       2919 non-null int64
# YearBuilt        2919 non-null int64
# YearRemodAdd     2919 non-null int64
# YrSold           2919 non-null int64
# dtypes: float64(12), int64(25), object(43)
# memory usage: 1.8+ MB

# %%
# According to Data Description some datatypes are incorrect so lets fix them. 
# MSSubClass, OverallQual and OverallCond are, actually, categorical.
for feature in ['MSSubClass', 'OverallQual', 'OverallCond']:
    all_data[feature] = all_data[feature].astype('object')

# %%
all_data[all_data['SalePrice'] > 0].sample(10)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 597       1402         0          0   NaN             2   TwnhsE       TA
# 474       1652         0          0   NaN             2   TwnhsE       TA
# 97         960         0          0   NaN             3     1Fam       TA
# 348        764       862          0   NaN             2    Twnhs       TA
# 476       1493         0          0   NaN             3     1Fam       TA
# 311        972         0          0   NaN             2     1Fam       TA
# 1408       741       622          0   NaN             3     1Fam       TA
# 636        800         0          0   NaN             1     1Fam       Fa
# 1046      1992       876          0   NaN             4     1Fam       TA
# 1143      1006         0          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 597            Av         0.0         0.0          Unf          Unf
# 474            Av      1196.0         0.0          GLQ          Unf
# 97             No       520.0         0.0          Rec          Unf
# 348            No       573.0         0.0          GLQ          Unf
# 476            Gd       994.0         0.0          GLQ          Unf
# 311            No       680.0         0.0          ALQ          Unf
# 1408           No         0.0         0.0          Unf          Unf
# 636            No         0.0         0.0          Unf          Unf
# 1046           Av       240.0         0.0          GLQ          Unf
# 1143           No       288.0         0.0          GLQ          Unf
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 597            0.0           2.0       Ex     1258.0          Y       Norm
# 474            1.0           0.0       Gd      298.0          Y       Norm
# 97             1.0           0.0       TA      440.0          Y       Norm
# 348            1.0           0.0       Gd      191.0          Y       Norm
# 476            1.0           0.0       Gd      484.0          Y       Norm
# 311            1.0           0.0       TA      292.0          Y       Norm
# 1408           0.0           0.0       Fa      622.0          Y       Norm
# 636            0.0           0.0       TA      264.0          N       Norm
# 1046           0.0           0.0       Ex     1752.0          Y       Norm
# 1143           0.0           0.0       TA      718.0          Y       Norm
#
#      Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 597        Norm      SBrkr              0        TA        Gd     VinylSd
# 474        Norm      SBrkr              0        TA        Gd     CemntBd
# 97         Norm      FuseF              0        TA        TA     HdBoard
# 348        Norm      SBrkr              0        TA        Gd     VinylSd
# 476        Norm      SBrkr              0        TA        TA     VinylSd
# 311        Norm      SBrkr              0        Gd        TA     VinylSd
# 1408       Norm      SBrkr              0        TA        TA     VinylSd
# 636        Norm      FuseA              0        Fa        Fa     AsbShng
# 1046       Norm      SBrkr              0        TA        Gd     CemntBd
# 1143       Norm      SBrkr              0        TA        TA     Wd Sdng
#
#      Exterior2nd Fence FireplaceQu  Fireplaces Foundation  FullBath  \
# 597      VinylSd   NaN          Gd           1      PConc         0
# 474      CmentBd   NaN         NaN           0      PConc         2
# 97       HdBoard   NaN         NaN           0     CBlock         1
# 348      Wd Shng   NaN         NaN           0      PConc         2
# 476      VinylSd   NaN          TA           1      PConc         2
# 311      VinylSd   NaN          Gd           1     CBlock         1
# 1408     VinylSd   NaN         NaN           0     CBlock         1
# 636      AsbShng   NaN          Po           1     BrkTil         1
# 1046     CmentBd   NaN          Gd           1      PConc         3
# 1143     Plywood   NaN         NaN           0     CBlock         1
#
#      Functional  GarageArea  GarageCars GarageCond GarageFinish GarageQual  \
# 597         Typ       648.0         3.0         TA          Fin         TA
# 474         Typ       499.0         2.0         TA          RFn         TA
# 97          Typ       432.0         1.0         TA          Fin         TA
# 348         Typ       474.0         2.0         TA          RFn         TA
# 476         Typ       508.0         2.0         TA          Fin         TA
# 311         Typ       240.0         1.0         TA          Unf         TA
# 1408        Typ       528.0         2.0         TA          Unf         TA
# 636        Maj1         0.0         0.0        NaN          NaN        NaN
# 1046        Typ       716.0         3.0         TA          Fin         TA
# 1143        Typ         0.0         0.0        NaN          NaN        NaN
#
#      GarageType  GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC  \
# 597      Attchd       2006.0       1402         2    GasA        Ex
# 474      Attchd       2000.0       1652         0    GasA        Ex
# 97       Attchd       1965.0        960         0    GasA        TA
# 348     BuiltIn       2003.0       1626         1    GasA        Ex
# 476      Attchd       1997.0       1493         0    GasA        Ex
# 311      Detchd       1948.0        972         0    GasA        Ex
# 1408     Detchd       1966.0       1363         0    GasA        Gd
# 636         NaN          NaN        800         0    Grav        Fa
# 1046    BuiltIn       2005.0       2868         1    GasA        Ex
# 1143        NaN          NaN       1006         0    GasA        TA
#
#      HouseStyle  KitchenAbvGr KitchenQual LandContour LandSlope  LotArea  \
# 597      1Story             1          Gd         Lvl       Gtl     3922
# 474      1Story             1          Ex         Lvl       Gtl     5330
# 97       1Story             1          TA         HLS       Gtl    10921
# 348      2Story             1          Gd         Lvl       Gtl     2448
# 476      1Story             1          Gd         Lvl       Mod    13125
# 311      1Story             1          TA         Lvl       Gtl     8000
# 1408     2Story             1          TA         Lvl       Gtl     7740
# 636      1Story             1          Fa         Lvl       Gtl     6120
# 1046     2Story             1          Ex         Lvl       Gtl    16056
# 1143     1Story             1          TA         Lvl       Gtl     9000
#
#      LotConfig  LotFrontage LotShape  LowQualFinSF MSSubClass MSZoning  \
# 597     Inside         53.0      Reg             0        120       RL
# 474     Inside         41.0      Reg             0        120       RL
# 97      Inside         73.0      Reg             0         20       RL
# 348     Inside         36.0      Reg             0        160       RL
# 476     Inside         75.0      Reg             0         20       RL
# 311     Inside         50.0      Reg             0         20       RL
# 1408    Inside         60.0      Reg             0         70       RM
# 636     Inside         51.0      Reg             0         30       RM
# 1046    Inside         85.0      IR1             0         60       RL
# 1143    Inside          NaN      Reg             0         20       RL
#
#       MasVnrArea MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  \
# 597         72.0    BrkFace         NaN        0       2      Blmngtn
# 474          0.0       None         NaN        0       8      StoneBr
# 97          48.0    BrkFace         NaN        0       5      Edwards
# 348        106.0      Stone         NaN        0      10      NridgHt
# 476        215.0    BrkFace         NaN        0       4      CollgCr
# 311          0.0       None         NaN        0       5        NAmes
# 1408         0.0       None         NaN        0       6      OldTown
# 636          0.0       None         NaN        0       1      BrkSide
# 1046       208.0      Stone         NaN        0       7      StoneBr
# 1143         0.0       None         NaN        0       7       Sawyer
#
#       OpenPorchSF OverallCond OverallQual PavedDrive  PoolArea PoolQC  \
# 597            16           5           7          Y         0    NaN
# 474            48           5           8          Y         0    NaN
# 97              0           5           4          P         0    NaN
# 348            27           5           7          Y         0    NaN
# 476            39           5           6          Y         0    NaN
# 311             0           6           6          Y         0    NaN
# 1408            0           7           4          Y         0    NaN
# 636             0           3           2          N         0    NaN
# 1046          108           5           9          Y         0    NaN
# 1143           24           3           5          Y         0    NaN
#
#      RoofMatl RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch Street  \
# 597   CompShg     Gable       Partial   194201.0      New            0   Pave
# 474   CompShg     Gable        Normal   251000.0       WD            0   Pave
# 97    CompShg       Hip        Normal    94750.0       WD            0   Pave
# 348   CompShg     Gable        Normal   154000.0       WD            0   Pave
# 476   CompShg     Gable        Normal   208900.0       WD            0   Pave
# 311   CompShg     Gable        Normal   132000.0       WD            0   Pave
# 1408  CompShg     Gable        Normal   125500.0       WD          168   Pave
# 636   CompShg     Gable        Normal    60000.0    ConLw            0   Pave
# 1046  CompShg       Hip       Partial   556581.0      New            0   Pave
# 1143  CompShg     Gable        Normal    80000.0       WD            0   Pave
#
#       TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  \
# 597              7       1258.0    AllPub         120       2006
# 474              6       1494.0    AllPub          96       2000
# 97               6        960.0    AllPub         120       1965
# 348              6        764.0    AllPub           0       2003
# 476              7       1478.0    AllPub         140       1997
# 311              5        972.0    AllPub           0       1948
# 1408             6        622.0    AllPub           0       1910
# 636              4        264.0    AllPub           0       1936
# 1046            11       1992.0    AllPub         214       2005
# 1143             5       1006.0    AllPub           0       1959
#
#       YearRemodAdd  YrSold
# 597           2007    2007
# 474           2000    2007
# 97            1965    2007
# 348           2004    2008
# 476           1998    2008
# 311           2002    2009
# 1408          1950    2010
# 636           1950    2009
# 1046          2006    2006
# 1143          1959    2008

# %%
all_data[all_data['SalePrice'] > 0].describe().transpose()
# Out:
#                 count           mean           std      min        25%  \
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
#
#                     50%        75%       max
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# 3SsnPorch           0.0       0.00     508.0
# BedroomAbvGr        3.0       3.00       8.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# BsmtUnfSF         477.5     808.00    2336.0
# EnclosedPorch       0.0       0.00     552.0
# Fireplaces          1.0       1.00       3.0
# FullBath            2.0       2.00       3.0
# GarageArea        480.0     576.00    1418.0
# GarageCars          2.0       2.00       4.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GrLivArea        1464.0    1776.75    5642.0
# HalfBath            0.0       1.00       2.0
# KitchenAbvGr        1.0       1.00       3.0
# LotArea          9478.5   11601.50  215245.0
# LotFrontage        69.0      80.00     313.0
# LowQualFinSF        0.0       0.00     572.0
# MasVnrArea          0.0     166.00    1600.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# OpenPorchSF        25.0      68.00     547.0
# PoolArea            0.0       0.00     738.0
# SalePrice      163000.0  214000.00  755000.0
# ScreenPorch         0.0       0.00     480.0
# TotRmsAbvGrd        6.0       7.00      14.0
# TotalBsmtSF       991.5    1298.25    6110.0
# WoodDeckSF          0.0     168.00     857.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# YrSold           2008.0    2009.00    2010.0

# %% [markdown]
# ## Outlier Detection

# %%
sns.jointplot(data=all_data[all_data['SalePrice'] > 0], x='GrLivArea', y='SalePrice')

# %%
all_data[(all_data['SalePrice'] > 0) & (all_data['GrLivArea'] > 4000)]
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 523       3138      1538          0   NaN             3     1Fam       TA
# 691       2444      1872          0   NaN             4     1Fam       TA
# 1182      2411      2065          0   NaN             4     1Fam       TA
# 1298      4692       950          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 523            Gd      2260.0         0.0          GLQ          Unf
# 691            Gd      1455.0         0.0          GLQ          Unf
# 1182           Av      2096.0         0.0          GLQ          Unf
# 1298           Gd      5644.0         0.0          GLQ          Unf
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 523            1.0           0.0       Ex      878.0          Y       PosN
# 691            0.0           1.0       Ex      989.0          Y       Norm
# 1182           1.0           0.0       Ex      300.0          Y       Norm
# 1298           2.0           0.0       Ex      466.0          Y      Feedr
#
#      Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 523        PosN      SBrkr              0        TA        Ex     CemntBd
# 691        Norm      SBrkr              0        TA        Ex     HdBoard
# 1182       Norm      SBrkr              0        TA        Gd     Wd Sdng
# 1298       Norm      SBrkr              0        TA        Ex      Stucco
#
#      Exterior2nd  Fence FireplaceQu  Fireplaces Foundation  FullBath  \
# 523      CmentBd    NaN          Gd           1      PConc         3
# 691      HdBoard    NaN          Ex           2      PConc         3
# 1182     ImStucc  MnPrv          TA           2      PConc         3
# 1298      Stucco    NaN          Gd           3      PConc         2
#
#      Functional  GarageArea  GarageCars GarageCond GarageFinish GarageQual  \
# 523         Typ       884.0         3.0         TA          Fin         TA
# 691         Typ       832.0         3.0         TA          Fin         TA
# 1182        Typ       813.0         3.0         TA          Fin         TA
# 1298        Typ      1418.0         2.0         TA          Fin         TA
#
#      GarageType  GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC  \
# 523     BuiltIn       2007.0       4676         1    GasA        Ex
# 691      Attchd       1994.0       4316         1    GasA        Ex
# 1182     Attchd       1996.0       4476         1    GasA        Ex
# 1298     Attchd       2008.0       5642         1    GasA        Ex
#
#      HouseStyle  KitchenAbvGr KitchenQual LandContour LandSlope  LotArea  \
# 523      2Story             1          Ex         Bnk       Gtl    40094
# 691      2Story             1          Ex         Lvl       Gtl    21535
# 1182     2Story             1          Ex         Lvl       Gtl    15623
# 1298     2Story             1          Ex         Bnk       Gtl    63887
#
#      LotConfig  LotFrontage LotShape  LowQualFinSF MSSubClass MSZoning  \
# 523     Inside        130.0      IR1             0         60       RL
# 691     Corner        104.0      IR1             0         60       RL
# 1182    Corner        160.0      IR1             0         60       RL
# 1298    Corner        313.0      IR3             0         60       RL
#
#       MasVnrArea MasVnrType MiscFeature  MiscVal  MoSold Neighborhood  \
# 523        762.0      Stone         NaN        0      10      Edwards
# 691       1170.0    BrkFace         NaN        0       1      NoRidge
# 1182         0.0       None         NaN        0       7      NoRidge
# 1298       796.0      Stone         NaN        0       1      Edwards
#
#       OpenPorchSF OverallCond OverallQual PavedDrive  PoolArea PoolQC  \
# 523           406           5          10          Y         0    NaN
# 691            50           6          10          Y         0    NaN
# 1182           78           5          10          Y       555     Ex
# 1298          292           5          10          Y       480     Gd
#
#      RoofMatl RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch Street  \
# 523   CompShg       Hip       Partial   184750.0      New            0   Pave
# 691   WdShngl     Gable        Normal   755000.0       WD            0   Pave
# 1182  CompShg       Hip       Abnorml   745000.0       WD            0   Pave
# 1298  ClyTile       Hip       Partial   160000.0      New            0   Pave
#
#       TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  \
# 523             11       3138.0    AllPub         208       2007
# 691             10       2444.0    AllPub         382       1994
# 1182            10       2396.0    AllPub         171       1996
# 1298            12       6110.0    AllPub         214       2008
#
#       YearRemodAdd  YrSold
# 523           2008    2007
# 691           1995    2007
# 1182          1996    2007
# 1298          2008    2008

# %%
# Well, these houses can be considered outliers.
all_data.drop(all_data[(all_data['SalePrice'] > 0) & (all_data['GrLivArea'] > 4000)].index, inplace=True)

# %% [markdown]
# ----

# %% [markdown]
# ## Missing Values

# %%
def missing_ratio(df):
    missing = (df.isnull().sum() / df.shape[0]) * 100
    df_nulls = pd.DataFrame(data={'Column': missing.index.values, 'Count': df.isnull().sum().values, 'Ratio': missing.values})
    df_nulls.sort_values(by='Ratio', ascending=False, inplace=True)
    return df_nulls

# %%
null_ratios = missing_ratio(all_data)
null_ratios[null_ratios['Count'] > 0]
# Out:
#           Column  Count      Ratio
# 65        PoolQC   2907  99.725557
# 56   MiscFeature   2810  96.397942
# 3          Alley   2717  93.207547
# 25         Fence   2345  80.445969
# 26   FireplaceQu   1420  48.713551
# 49   LotFrontage    486  16.672384
# 37   GarageYrBlt    159   5.454545
# 35    GarageQual    159   5.454545
# 34  GarageFinish    159   5.454545
# 33    GarageCond    159   5.454545
# 36    GarageType    157   5.385935
# 6       BsmtCond     82   2.813036
# 7   BsmtExposure     82   2.813036
# 14      BsmtQual     81   2.778731
# 11  BsmtFinType2     80   2.744425
# 10  BsmtFinType1     79   2.710120
# 55    MasVnrType     24   0.823328
# 54    MasVnrArea     23   0.789022
# 53      MSZoning      4   0.137221
# 13  BsmtHalfBath      2   0.068611
# 12  BsmtFullBath      2   0.068611
# 75     Utilities      2   0.068611
# 30    Functional      2   0.068611
# 23   Exterior1st      1   0.034305
# 31    GarageArea      1   0.034305
# 8     BsmtFinSF1      1   0.034305
# 9     BsmtFinSF2      1   0.034305
# 19    Electrical      1   0.034305
# 15     BsmtUnfSF      1   0.034305
# 24   Exterior2nd      1   0.034305
# 32    GarageCars      1   0.034305
# 70      SaleType      1   0.034305
# 74   TotalBsmtSF      1   0.034305
# 44   KitchenQual      1   0.034305

# %% [markdown]
# ### LotFrontage

# %%
by_neighbor = all_data.groupby(by='Neighborhood', sort=True)
by_neighbor.median()['LotFrontage']
# Out:
# Neighborhood
# Blmngtn    43.0
# Blueste    24.0
# BrDale     21.0
# BrkSide    51.0
# ClearCr    80.5
# CollgCr    70.0
# Crawfor    70.0
# Edwards    64.5
# Gilbert    64.0
# IDOTRR     60.0
# MeadowV    21.0
# Mitchel    74.0
# NAmes      73.0
# NPkVill    24.0
# NWAmes     80.0
# NoRidge    88.5
# NridgHt    92.0
# OldTown    60.0
# SWISU      60.0
# Sawyer     72.0
# SawyerW    67.0
# Somerst    72.5
# StoneBr    60.0
# Timber     82.0
# Veenker    80.0
# Name: LotFrontage, dtype: float64

# %%
# Replace the NaN's in LotFrontage with the neighborhood's median.
def neighborhood_median(row):
    median = by_neighbor['LotFrontage'].median()[row['Neighborhood']]
    return median

all_data['LotFrontage'] = all_data.apply(lambda row: neighborhood_median(row) if np.isnan(row['LotFrontage']) else row['LotFrontage'], axis=1)

# %%
# Numeric features...
all_data.fillna({'GarageArea': 0, 
                 'GarageCars': 0,
                 'TotalBsmtSF': 0,
                 'BsmtFullBath': 0,
                 'BsmtHalfBath': 0,
                 'BsmtFinSF1': 0,
                 'BsmtFinSF2': 0,
                 'BsmtUnfSF': 0,
                 'MasVnrArea': 0, 
                 'MasVnrType': 'None'}, inplace=True)

# Columns that are going to be filled with the mode.
mode_columns = ['Electrical', 'MSZoning', 'Utilities', 'Functional', 'Exterior1st', 'Exterior2nd', 'SaleType', 'KitchenQual']
for col in mode_columns:
    all_data.fillna({col: all_data[col].mode()[0]}, inplace=True)    

# Replace GarageCond, GarageType, GarageFinish, GarageQual and GarageYrBlt "NaN's" with "NA" when GarageArea = 0;
mask = (all_data['GarageArea'] == 0)
all_data.loc[mask, ['GarageCond','GarageType','GarageFinish','GarageQual','GarageYrBlt']] = "NA"

# Replace GarageCond, GarageType, GarageFinish, GarageQual and GarageYrBlt "NaN's" with "None" when GarageArea > 0;
mask = (all_data['GarageArea'] > 0)
all_data.loc[mask, ['GarageCond','GarageType','GarageFinish','GarageQual','GarageYrBlt']] = "None"

# Replace BsmtQual, BsmtCond, BsmtFinType1, BsmtFinType2 and BsmtExposure "NaN's" with "NA" when TotalBsmtSF = 0;
mask = (all_data['TotalBsmtSF'] == 0)
all_data.loc[mask, ['BsmtQual','BsmtCond','BsmtFinType1','BsmtFinType2','BsmtExposure']] = "NA"

# Replace BsmtQual, BsmtCond, BsmtFinType1, BsmtFinType2 and BsmtExposure "NaN's" with "None" when TotalBsmtSF > 0;
mask = (all_data['TotalBsmtSF'] > 0)
all_data.loc[mask, ['BsmtQual', 'BsmtCond', 'BsmtFinType1', 'BsmtFinType2', 'BsmtExposure']] = "None"

# %% [markdown]
# `PoolQC`, `MiscFeature`, `Alley`, `Fence` and `FireplaceQu` have too many null values. I'm not inputing these features because an input of more than 50% would distort the feature too much. I also dont think they are so important for the predictions so im just discarding these features

# %%
all_data.drop(['PoolQC','MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=1, inplace=True)

# %%
# Checking for remaining NaN's
null_ratios = missing_ratio(all_data)
null_ratios[null_ratios['Count'] > 0]
# Out:
# Empty DataFrame
# Columns: [Column, Count, Ratio]
# Index: []

# %% [markdown]
# ---

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# The objective of this step is to know the data, the relations between the variables and the distributions of the features.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ### Correlation Matrix

# %%
# Plot a heatmap to understand how the features are correlated with the target (SalePrice).
plt.figure(figsize=(15,10))
sns.heatmap(df_train.corr(), cmap='RdYlBu', linewidths=.01, linecolor='black', vmin=-0.6, vmax=1)

# %% [markdown]
# - `TotalBsmtSF`, `1stFlrSF`, `GrLivArea`, `GarageCars`, `GarageArea` and `FullBath` are the most correlated features w/ `SalePrice`.
# - `TotalBsmtSF` and `1stFlrSF` are strongly correlated.
# - `GrLivArea` and `TotRmsAbvGrd` are strongly correlated.
# - `GarageCars` and `GarageArea`are strongly correlated.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### TotalSF

# %% [markdown]
# In order to remove the multicolinearity between TotalBsmtSF and 1stFlrSF i'm creating a new feature called `TotalSF`, where:<br>
# <b>TotalSF = TotalBsmtSF + 1stFlrSF + 2ndFlrSF <br></b>
# This will be like my 'main' feature for the house size. <br>
# It also replaces <b>GrLivArea</b> because of multicolinearity.

# %%
#all_data['TotalSF'] = all_data['1stFlrSF'] + all_data['2ndFlrSF']
#all_data.drop(['TotalBsmtSF','1stFlrSF','2ndFlrSF', 'GrLivArea'], axis=1, inplace=True)

# %%
#sns.jointplot(x = all_data[all_data['test'] == False]['TotalSF'], y=df_train['SalePrice'])

# %% [markdown]
# ### HouseAge

# %% [markdown]
# This feature represents the age of the house in the moment of the sale, ie the difference between the year of sale and year of construction.

# %%
#all_data['HouseAge'] = all_data.apply(lambda x: x['YrSold'] - x['YearBuilt'] if x['YrSold'] >= x['YearBuilt'] else 0, axis=1)
all_data.drop(['YrSold', 'YearBuilt'], axis=1, inplace=True)

# %%
#sns.jointplot(data=all_data[all_data['SalePrice'] > 0], x='HouseAge', y='SalePrice')

# %% [markdown]
# ### HasPool

# %% [markdown]
# Even though `PoolArea` isn't highly correlated with saleprice, a pool would certainly increase the price of a house, so I'm creating a flag to indicate if there's a pool or not.

# %%
all_data['HasPool'] = all_data['PoolArea'].apply(lambda x: 'Y' if x > 0 else 'N')
all_data.drop('PoolArea', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='HasPool', y='SalePrice')

# %%
all_data = pd.get_dummies(all_data, drop_first=True, columns=['HasPool'])

# %% [markdown]
# ### Bathrooms

# %% [markdown]
# This feature represents the number of bathrooms in the house: <br>
# <b>Bathrooms = FullBath + HalfBath + BsmtFullBath + BsmtHalfBath </b> <br>

# %%
#all_data['Bathrooms'] = all_data['FullBath'] + all_data['HalfBath'] + all_data['BsmtFullBath'] + all_data['BsmtHalfBath']
all_data.drop(['FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath'], axis=1, inplace=True)

# %%
#plt.figure(figsize=(10,5))
#sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='Bathrooms', y='SalePrice')

# %% [markdown]
# ### TotalBsmtSFFin

# %% [markdown]
# This feature represents the total finished square feet of basement area.

# %%
all_data['TotalBsmtSFFin'] = all_data['TotalBsmtSF'] - all_data['BsmtUnfSF']
all_data['HasBsmt'] = all_data['TotalBsmtSFFin'].apply(lambda x: 'Y' if x > 0 else 'N')
all_data.drop(['TotalBsmtSF', 'BsmtUnfSF', 'TotalBsmtSFFin'], axis=1, inplace=True)

# %%
#plt.figure(figsize=(10,5))
#sns.jointplot(data=all_data[all_data['SalePrice'] > 0], x='TotalBsmtSFFin', y='SalePrice')

# %%
all_data = pd.get_dummies(all_data, drop_first=True, columns=['HasBsmt'])

# %% [markdown]
# ### Polynomial Features

# %% [markdown]
# I'm also adding some polynomial features to capture non-linear relationships

# %%
# Creating the polynomial features...
#all_data['GrLivArea'] = all_data['TotalSF'] ** 2
#all_data['HouseAge-2'] = all_data['HouseAge'] ** 2
#all_data['GarageCars-2'] = all_data['GarageCars'] ** 2
#all_data['HouseAge-Rec'] = all_data.apply(lambda x: 1 / x['HouseAge'] if x['HouseAge'] > 0 else 0, axis=1)

# %%
# Drop the unused features
all_data.drop(['LotFrontage',
               'YearRemodAdd',
               'MasVnrArea',
               'BsmtFinSF1',
               'BsmtFinSF2',
               'LowQualFinSF',
               'BedroomAbvGr',
               'KitchenAbvGr',
               'TotRmsAbvGrd',
               'Fireplaces',
               'GarageArea',
               'WoodDeckSF',
               'OpenPorchSF',
               'EnclosedPorch',
               '3SsnPorch',
               'ScreenPorch',
               'MiscVal',
               'MoSold',
               '1stFlrSF',
               '2ndFlrSF'], axis=1, inplace=True)

# %%
sns.heatmap(data=all_data[all_data['SalePrice'] > 0].corr(), cmap='RdYlBu', 
            linewidths=.01, linecolor='black', vmin=-0.6, vmax=1, annot=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ### OverallQual

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='OverallQual', y='SalePrice')

# %% [markdown]
# ### ExterCond

# %%
plt.subplots(figsize=(20, 5))

plt.subplot(1, 2, 1)
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='ExterCond', y='SalePrice', order=['Po','Fa','TA','Gd','Ex'])

plt.subplot(1, 2, 2)
sns.barplot(data=all_data[all_data['SalePrice'] > 0], x='ExterCond', y='SalePrice', order=['Po','Fa','TA','Gd','Ex'])

# %%
all_data = pd.get_dummies(all_data, drop_first=True, columns=['ExterCond'])

# %% [markdown]
# ### KitchenQual

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='KitchenQual', y='SalePrice', order=['Fa','TA','Gd','Ex'])

# %%
all_data.replace({'KitchenQual': {'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4}}, inplace=True)

# %% [markdown]
# ### Neighborhood

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='Neighborhood', y='SalePrice')

# %%
all_data = pd.get_dummies(all_data, drop_first=True, columns=['Neighborhood'])

# %% [markdown]
# ### SaleCondition

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
sns.boxplot(data=all_data[all_data['SalePrice'] > 0], x='SaleCondition', y='SalePrice')

# %%
all_data = pd.get_dummies(all_data, drop_first=True, columns=['SaleCondition'])

# %% [markdown]
# ---

# %% [markdown]
# ## VIF Test

# %% [markdown]
# The variance inflation factor is a measure for the increase of the variance of the parameter estimates if an additional variable, given by exog_idx is added to the linear regression. It is a measure for multicollinearity of the design matrix, exog. One recommendation is that if VIF is greater than 5, then the explanatory variable given by exog_idx is highly collinear with the other explanatory variables, and the parameter estimates will have large standard errors because of this.

# %%
X = all_data.select_dtypes(include=np.number)
X.insert(0,'const',1)
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#     VIF Factor               features
# 0   437.217781                  const
# 1     1.944387             GarageCars
# 2     1.781327              GrLivArea
# 3     1.938937            KitchenQual
# 4     1.265185                LotArea
# 5     1.148811              SalePrice
# 6     1.025851              HasPool_Y
# 7     1.171431              HasBsmt_Y
# 8     6.640972           ExterCond_Fa
# 9    23.774748           ExterCond_Gd
# 10    1.274417           ExterCond_Po
# 11   28.575364           ExterCond_TA
# 12    1.369997   Neighborhood_Blueste
# 13    2.125830    Neighborhood_BrDale
# 14    4.984726   Neighborhood_BrkSide
# 15    2.740515   Neighborhood_ClearCr
# 16    9.736512   Neighborhood_CollgCr
# 17    4.753263   Neighborhood_Crawfor
# 18    7.876912   Neighborhood_Edwards
# 19    6.685629   Neighborhood_Gilbert
# 20    4.561415    Neighborhood_IDOTRR
# 21    2.420237   Neighborhood_MeadowV
# 22    5.112517   Neighborhood_Mitchel
# 23   15.141441     Neighborhood_NAmes
# 24    1.850047   Neighborhood_NPkVill
# 25    5.674704    Neighborhood_NWAmes
# 26    3.598154   Neighborhood_NoRidge
# 27    6.691546   Neighborhood_NridgHt
# 28    9.381481   Neighborhood_OldTown
# 29    2.874498     Neighborhood_SWISU
# 30    6.429951    Neighborhood_Sawyer
# 31    5.387607   Neighborhood_SawyerW
# 32    7.072731   Neighborhood_Somerst
# 33    2.823130   Neighborhood_StoneBr
# 34    3.602689    Neighborhood_Timber
# 35    1.914089   Neighborhood_Veenker
# 36    1.094629  SaleCondition_AdjLand
# 37    1.159500   SaleCondition_Alloca
# 38    1.237762   SaleCondition_Family
# 39    2.485158   SaleCondition_Normal
# 40    2.511850  SaleCondition_Partial

# %%
all_data.drop(['MSSubClass',
 'MSZoning',
 'Street',
 'LotShape',
 'LandContour',
 'Utilities',
 'LotConfig',
 'LandSlope',
 'Condition1',
 'Condition2',
 'BldgType',
 'HouseStyle',
 'OverallCond',
 'RoofStyle',
 'RoofMatl',
 'Exterior1st',
 'Exterior2nd',
 'MasVnrType',
 'ExterQual',
 'Foundation',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'Heating',
 'HeatingQC',
 'CentralAir',
 'Electrical',
 'Functional',
 'GarageType',
 'GarageYrBlt',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PavedDrive',
 'SaleType'], axis=1, inplace=True)

# %% [markdown]
# ## Target Variable

# %%
plt.figure(figsize=(15,5))
sns.distplot(all_data[all_data['SalePrice'] > 0]['SalePrice'], color='green')

# %% [markdown]
# - The target variable `SalePrice` is not normally distributed. A transformation will be required.

# %%
# Applying log transformation.
all_data.loc[all_data['SalePrice'] > 0, 'SalePrice'] = np.log(all_data.loc[all_data['SalePrice'] > 0, 'SalePrice'])

# %%
plt.figure(figsize=(15,5))
sns.distplot(all_data[all_data['SalePrice'] > 0]['SalePrice'], color='green')

# %% [markdown]
# ## Skewed Features

# %%
df_skew = pd.DataFrame(columns=['Column', 'Skewness'])
for feature in all_data.select_dtypes(exclude='object').columns:
    df_skew = df_skew.append({'Column': feature , 'Skewness': abs(skew(all_data[feature]))}, ignore_index=True)
df_skew = df_skew[df_skew['Skewness'] >= 0.5]

plt.figure(figsize=(15,5))
plt.xticks(rotation=90)
sns.barplot(data=df_skew.sort_values(by='Skewness'), x='Column', y='Skewness')

# %%
for feature in df_skew['Column']:
    all_data[feature] = np.log1p(all_data[feature])

# %% [markdown]
# ## Model / Validation

# %% [markdown]
# ### General Definitions

# %%
# Cross Validation Strategy...
cv = ShuffleSplit(n_splits=10, test_size=0.3, random_state=0)

# Score to be evaluated
scoring = 'neg_mean_squared_error'

# %% [markdown]
# ### Train/Test Split

# %%
y_train = all_data.loc[all_data['SalePrice'] > 0, 'SalePrice']
X_train = all_data.loc[all_data['SalePrice'] > 0].drop('SalePrice', axis=1)
X_test = all_data.loc[all_data['SalePrice'] == 0].drop('SalePrice', axis=1)

print('Train Set: {}, {}'.format(X_train.shape[0], X_train.shape[1]))
print('Test Set: {}, {}'.format(X_test.shape[0], X_test.shape[1]))
# Out:
# Train Set: 1456, 40
# Test Set: 1459, 40

# %%
X_train.columns
# Out:
# Index(['GarageCars', 'GrLivArea', 'KitchenQual', 'LotArea', 'OverallQual',
#        'HasPool_Y', 'HasBsmt_Y', 'ExterCond_Fa', 'ExterCond_Gd',
#        'ExterCond_Po', 'ExterCond_TA', 'Neighborhood_Blueste',
#        'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_ClearCr',
#        'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 'Neighborhood_Edwards',
#        'Neighborhood_Gilbert', 'Neighborhood_IDOTRR', 'Neighborhood_MeadowV',
#        'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NPkVill',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
#        'Neighborhood_OldTown', 'Neighborhood_SWISU', 'Neighborhood_Sawyer',
#        'Neighborhood_SawyerW', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
#        'Neighborhood_Timber', 'Neighborhood_Veenker', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object')

# %% [markdown]
# ### Standartization

# %%
print('Scaling Features...')
scaler = StandardScaler()
X_train[X_train.columns] = scaler.fit_transform(X_train[X_train.columns])
X_test[X_test.columns] = scaler.transform(X_test[X_test.columns])
print('Scaling OK')
# Out:
# Scaling Features...
# Scaling OK

# %% [markdown]
# ### Alpha (Regularization) Tuning

# %%
# Finding best value of Alpha
df_alphas = pd.DataFrame(columns=['Alpha', 'RMSE'])
alphas = []

for alpha in np.logspace(-10, 1, 300):
    
    list_mse = []
    rmse = 0
    model = Lasso(alpha=alpha)

    for train_index, test_index in cv.split(X_train, y_train):
        X_train_cv, X_test_cv = X_train.iloc[train_index], X_train.iloc[test_index]
        y_train_cv, y_test_cv = y_train.iloc[train_index], y_train.iloc[test_index]

        model.fit(X_train_cv, y_train_cv)
        predictions = model.predict(X_test_cv)
        
        rmse = np.sqrt(mean_squared_error(y_test_cv, predictions))
        list_mse.append(rmse)
                                       
    df_alphas = df_alphas.append({'Alpha': alpha, 'RMSE': np.mean(list_mse)}, ignore_index=True)

df_alphas.sort_values(by='RMSE', inplace=True)
df_alphas.head()
# Out:
#         Alpha      RMSE
# 198  0.001924  0.135281
# 197  0.001768  0.135281
# 196  0.001624  0.135288
# 199  0.002094  0.135289
# 195  0.001492  0.135300

# %%
#my_alpha = 0.0008 w/ BathRoom feature included
my_alpha = 0.001
model = Lasso(alpha=my_alpha) # score kaggle: 0.14242

# %% [markdown]
# ### Model Evaluation -  Learning Curves

# %%
# Define train set sizes
train_sizes = np.linspace(.1, 1.0, 5)

train_sizes, train_scores, test_scores = learning_curve(model, X_train, y_train, cv=cv, train_sizes=train_sizes, scoring=scoring)
train_rmse = np.sqrt(-np.mean(train_scores, axis=1))
cv_rmse = np.sqrt(-np.mean(test_scores, axis=1))

plt.figure(figsize=(15,5))
plt.title("Learning Curve - Lasso Regression - Alpha = %.4f" % my_alpha)
plt.xlabel("Training examples")
plt.ylabel("RMSE")
plt.plot(train_sizes, train_rmse, 'o-', color="r", label="Training score")
plt.plot(train_sizes, cv_rmse, 'o-', color="b", label="Cross-validation score")

plt.legend(loc="best")
plt.show()

# %%
# Initial: 0.12700778579621239
#Last: 0.14382602818567541

# %%
score = np.mean(np.sqrt(-cross_val_score(model, X_train, y_train, cv=cv, scoring=scoring)))
score
# Out:
# 0.13536489448171637

# %%
X_train_cv, X_test_cv, y_train_cv, y_test_cv = train_test_split(X_train, y_train, test_size=0.3, random_state=0)
model.fit(X_train_cv, y_train_cv)
pred = model.predict(X_test_cv)

# %%
df_coefs = pd.DataFrame(columns=['Column', 'Coef'])
df_coefs['Column'] = X_test_cv.columns
df_coefs['Coef'] = model.coef_
df_coefs
# Out:
#                    Column      Coef
# 0              GarageCars  0.045020
# 1               GrLivArea  0.122431
# 2             KitchenQual  0.052691
# 3                 LotArea  0.055628
# 4             OverallQual  0.118479
# 5               HasPool_Y  0.001211
# 6               HasBsmt_Y  0.048217
# 7            ExterCond_Fa -0.019933
# 8            ExterCond_Gd  0.004380
# 9            ExterCond_Po -0.002331
# 10           ExterCond_TA -0.000000
# 11   Neighborhood_Blueste -0.000000
# 12    Neighborhood_BrDale -0.012399
# 13   Neighborhood_BrkSide -0.002986
# 14   Neighborhood_ClearCr  0.009795
# 15   Neighborhood_CollgCr  0.007096
# 16   Neighborhood_Crawfor  0.016782
# 17   Neighborhood_Edwards -0.023507
# 18   Neighborhood_Gilbert  0.002312
# 19    Neighborhood_IDOTRR -0.031425
# 20   Neighborhood_MeadowV -0.006312
# 21   Neighborhood_Mitchel -0.000000
# 22     Neighborhood_NAmes -0.009320
# 23   Neighborhood_NPkVill  0.000000
# 24    Neighborhood_NWAmes -0.002419
# 25   Neighborhood_NoRidge  0.022129
# 26   Neighborhood_NridgHt  0.027265
# 27   Neighborhood_OldTown -0.039151
# 28     Neighborhood_SWISU -0.003597
# 29    Neighborhood_Sawyer -0.005341
# 30   Neighborhood_SawyerW -0.003815
# 31   Neighborhood_Somerst  0.014974
# 32   Neighborhood_StoneBr  0.020549
# 33    Neighborhood_Timber  0.002890
# 34   Neighborhood_Veenker  0.006614
# 35  SaleCondition_AdjLand  0.003642
# 36   SaleCondition_Alloca  0.009570
# 37   SaleCondition_Family -0.001357
# 38   SaleCondition_Normal  0.029686
# 39  SaleCondition_Partial  0.044424

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.scatter(y_test_cv, y_test_cv)
ax.plot([y_test_cv.min(), y_test_cv.max()], [pred.min(), pred.max()], c='r')
ax.set_title('SalePrice Predictions')
ax.set_xlabel('Real')
ax.set_ylabel('Predicted')
fig.show()

# %%
check = pd.DataFrame(columns=['real_value', 'prediction', 'real_value_transformed', 'prediction_transformed'])
check['real_value'] = y_test_cv
check['prediction'] = pred
check['real_value_transformed'] = np.exp(check['real_value'])
check['prediction_transformed'] = np.exp(check['prediction'])
check[check['real_value'] < 11.0]
# Out:
#       real_value  prediction  real_value_transformed  prediction_transformed
# 1337   10.868568   11.051281                 52500.0            63024.612034
# 916    10.471950   10.938479                 35311.0            56301.620371
# 968    10.542706   11.131142                 37900.0            68264.309740

# %%
df_train.loc[[1337, 916, 968]]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1337  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1337         Bnk    AllPub    Corner       Mod      OldTown      Feedr
# 916          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 968          Lvl    AllPub    Inside       Gtl      OldTown       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1337       Norm     1Fam     1Story            4            4       1941
# 916        Norm     1Fam     1Story            2            3       1949
# 968        Norm     1Fam     1.5Fin            3            6       1910
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1337          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 916           1950     Gable  CompShg     AsbShng     AsbShng       None
# 968           1950     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1337         0.0        TA        TA     CBlock       TA       TA
# 916          0.0        TA        TA     CBlock       TA       TA
# 968          0.0        TA        TA     BrkTil       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1337           No          Unf           0          Unf           0
# 916            Av          BLQ          50          Unf           0
# 968            No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1337        693          693    Grav        Fa          N      FuseA
# 916         430          480    GasA        TA          N      FuseA
# 968         600          600    Grav        Fa          N      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1337       693         0             0        693             0             0
# 916        480         0             0        480             1             0
# 968        600       368             0        968             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1337         1         0             2             1          Fa
# 916          0         0             1             1          TA
# 968          1         0             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1337             4        Typ           0         NaN        NaN          NaN
# 916              4        Typ           0         NaN     Detchd       1958.0
# 968              6        Typ           0         NaN        NaN          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1337          NaN           0           0        NaN        NaN          N
# 916           Unf           1         308         TA         TA          Y
# 968           NaN           0           0        NaN        NaN          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1337           0           20              0          0            0
# 916            0            0              0          0            0
# 968            0            0              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1337         0    NaN   NaN         NaN        0       3    2006       WD
# 916          0    NaN   NaN         NaN        0      10    2006       WD
# 968          0    NaN  GdWo         NaN        0       5    2009       WD
#
#      SaleCondition  SalePrice
# 1337        Normal      52500
# 916        Abnorml      35311
# 968        Abnorml      37900

# %% [markdown]
# ## Submission

# %%
model.fit(X_train, y_train)
sub_pred = model.predict(X_test)

# %%
submission['SalePrice'] = np.exp(sub_pred)
submission.to_csv('submission.csv',index=False)
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  121723.278668
# 1  1462  170588.882788
# 2  1463  169876.384262
# 3  1464  193348.616218
# 4  1465  224977.975399

# %%
# %%cmd
# @echo off
# #kaggle competitions submit -c house-prices-advanced-regression-techniques -f submission.csv -m "26/02/2019 - Teste C/ LotArea e KitchenQual"
# kaggle competitions submissions -c house-prices-advanced-regression-techniques
# Out:
# Microsoft Windows [versÆo 10.0.15063]
# (c) 2017 Microsoft Corporation. Todos os direitos reservados.
#
# c:\Projetos_Python\Kaggle\kaggle-house-prices-iowa>@echo off
# #kaggle competitions submit -c house-prices-advanced-regression-techniques -f submission.csv -m "26/02/2019 - Teste C/ LotArea e KitchenQual"
# kaggle competitions submissions -c house-prices-advanced-regression-techniques
# fileName        date                 description                                      status    publicScore  privateScore
# --------------  -------------------  -----------------------------------------------  --------  -----------  ------------
# submission.csv  2019-02-27 01:18:21  26/02/2019 - Teste C/ LotArea e KitchenQual      complete  0.14726      None
# submission.csv  2019-02-27 01:15:19  26/02/2019 - Teste C/ LotArea e Sem KitchenQual  complete  0.15161      None
# submission.csv  2019-02-27 00:39:43  26/02/2019 - Teste c/ Basement Finalizado        complete  0.15141      None
# submission.csv  2019-02-26 23:06:38  26/02/2019 - Teste 1                             complete  0.15464      None
# submission.csv  2019-02-26 22:25:52  26/02/2019 - Teste 1                             complete  0.15770      None
# submission.csv  2019-02-26 21:55:07  26/02/2019 - Teste 1                             complete  0.15555      None
# submission.csv  2019-02-26 01:13:24  Correct Standartization                          complete  0.15544      None
# submission.csv  2019-02-25 22:30:12  Correct Standartization                          complete  0.22293      None
# submission.csv  2019-02-24 23:36:30  Test Sub From Jupyter                            complete  0.22279      None
# submission.csv  2019-02-24 16:32:39  Test Sub From Jupyter                            complete  0.22719      None
# submission.csv  2019-02-24 16:08:39  Test Sub From Jupyter                            complete  0.29237      None
# submission.csv  2019-02-24 15:28:15  Test Sub From Jupyter                            complete  0.34539      None
# submission.csv  2019-02-24 14:58:56  Test Sub From Jupyter                            complete  0.23084      None
# submission.csv  2019-02-23 18:57:50  Test Sub From Jupyter                            complete  0.23538      None
# submission.csv  2019-02-22 01:45:27  None                                             complete  0.24258      None
# submission.csv  2019-02-21 01:24:43  None                                             complete  0.20236      None
# submission.csv  2019-02-20 23:47:38  None                                             complete  0.20071      None
# submission.csv  2019-02-20 23:43:21  None                                             complete  0.20071      None
# submission.csv  2019-02-20 00:43:20  None                                             complete  0.19185      None
# submission.csv  2019-02-19 00:53:48  None                                             complete  0.14242      None
# '#kaggle' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.
